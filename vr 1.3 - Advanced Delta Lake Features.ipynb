-- %% [markdown]
-- ## Delta Time Travel

-- %%
USE CATALOG hive_metastore
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
DESCRIBE HISTORY employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>6</td><td>2026-08-19T20:23:42Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> true)</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 5, numRemovedBytes -> 5947, p25FileSize -> 1295, numDeletionVectorsRemoved -> 1, minFileSize -> 1295, numAddedFiles -> 1, maxFileSize -> 1295, p75FileSize -> 1295, p50FileSize -> 1295, numAddedBytes -> 1295)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>5</td><td>2026-08-19T20:23:38Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>UPDATE</td><td>Map(predicate -> ["StartsWith(name#1739, A)"])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1173, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 3678, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1885, numAddedFiles -> 2, numUpdatedRows -> 2, numAddedBytes -> 2382, rewriteTimeMs -> 1765)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>4</td><td>2026-08-19T20:21:31Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1168)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>3</td><td>2026-08-19T20:21:30Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1173)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>2</td><td>2026-08-19T20:21:26Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 2, numOutputBytes -> 1200)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>1</td><td>2026-08-19T20:21:20Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 2, numOutputBytes -> 1197)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>0</td><td>2026-08-19T20:19:24Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], description -> null, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/14.3.x-phot ...

-- %%
SELECT * 
FROM employees VERSION AS OF 4
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>3</td><td>John</td><td>2999.3</td></tr><tr><td>4</td><td>Thomas</td><td>4000.3</td></tr><tr><td>1</td><td>Adam</td><td>3500.0</td></tr><tr><td>2</td><td>Sarah</td><td>4020.5</td></tr><tr><td>5</td><td>Anna</td><td>2500.0</td></tr><tr><td>6</td><td>Kim</td><td>6200.3</td></tr></tbody></table></div>

-- %%
SELECT * FROM employees@v4
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>3</td><td>John</td><td>2999.3</td></tr><tr><td>4</td><td>Thomas</td><td>4000.3</td></tr><tr><td>1</td><td>Adam</td><td>3500.0</td></tr><tr><td>2</td><td>Sarah</td><td>4020.5</td></tr><tr><td>5</td><td>Anna</td><td>2500.0</td></tr><tr><td>6</td><td>Kim</td><td>6200.3</td></tr></tbody></table></div>

-- %%
DELETE FROM employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>

-- %%
SELECT * FROM employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody></tbody></table></div>

-- %%
RESTORE TABLE employees TO VERSION AS OF 6
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>1295</td><td>1</td><td>0</td><td>1</td><td>0</td><td>1295</td></tr></tbody></table></div>

-- %%
SELECT * FROM employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Adam</td><td>3600.0</td></tr><tr><td>2</td><td>Sarah</td><td>4020.5</td></tr><tr><td>3</td><td>John</td><td>2999.3</td></tr><tr><td>4</td><td>Thomas</td><td>4000.3</td></tr><tr><td>5</td><td>Anna</td><td>2600.0</td></tr><tr><td>6</td><td>Kim</td><td>6200.3</td></tr></tbody></table></div>

-- %%
DESCRIBE HISTORY employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>8</td><td>2026-08-19T20:35:08Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>RESTORE</td><td>Map(version -> 6, timestamp -> null)</td><td>null</td><td>List(1438636061147701)</td><td>0819-110951-buv74slr</td><td>7</td><td>Serializable</td><td>false</td><td>Map(numRestoredFiles -> 1, removedFilesSize -> 0, numRemovedFiles -> 0, restoredFilesSize -> 1295, numOfFilesAfterRestore -> 1, tableSizeAfterRestore -> 1295)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>7</td><td>2026-08-19T20:34:40Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>DELETE</td><td>Map(predicate -> ["true"])</td><td>null</td><td>List(1438636061147701)</td><td>0819-110951-buv74slr</td><td>6</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1295, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 10, numDeletionVectorsUpdated -> 0, numDeletedRows -> 6, scanTimeMs -> 9, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>6</td><td>2026-08-19T20:23:42Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> true)</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 5, numRemovedBytes -> 5947, p25FileSize -> 1295, numDeletionVectorsRemoved -> 1, minFileSize -> 1295, numAddedFiles -> 1, maxFileSize -> 1295, p75FileSize -> 1295, p50FileSize -> 1295, numAddedBytes -> 1295)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>5</td><td>2026-08-19T20:23:38Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>UPDATE</td><td>Map(predicate -> ["StartsWith(name#1739, A)"])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1173, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 3678, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1885, numAddedFiles -> 2, numUpdatedRows -> 2, numAddedBytes -> 2382, rewriteTimeMs -> 1765)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>4</td><td>2026-08-19T20:21:31Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1168)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>3</td><td>2026-08-19T20:21:30Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1173)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>2</td><td>2026-08-19T20:21:26Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partiti ...

-- %% [markdown]
-- ## OPTIMIZE Command

-- %%
DESCRIBE DETAIL employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th></tr></thead><tbody><tr><td>delta</td><td>37747348-e480-4b12-9461-3aad0d1d0822</td><td>hive_metastore.default.employees</td><td>null</td><td>dbfs:/user/hive/warehouse/employees</td><td>2026-08-19T20:19:23.931Z</td><td>2026-08-19T20:35:08Z</td><td>List()</td><td>List()</td><td>1</td><td>1295</td><td>Map(delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(deletionVectors)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td></tr></tbody></table></div>

-- %%
OPTIMIZE employees
ZORDER BY id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1295), 0, List(0, 0), 0, null), 0, 1, 1, false, 0, 0, 1787171750869, 1787171753327, 4, 0, null, List(0, 0), 3, 3, 0, 0, null)</td></tr></tbody></table></div>

-- %%
DESCRIBE DETAIL employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th></tr></thead><tbody><tr><td>delta</td><td>37747348-e480-4b12-9461-3aad0d1d0822</td><td>hive_metastore.default.employees</td><td>null</td><td>dbfs:/user/hive/warehouse/employees</td><td>2026-08-19T20:19:23.931Z</td><td>2026-08-19T20:35:08Z</td><td>List()</td><td>List()</td><td>1</td><td>1295</td><td>Map(delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(deletionVectors)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td></tr></tbody></table></div>

-- %%
DESCRIBE HISTORY employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>8</td><td>2026-08-19T20:35:08Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>RESTORE</td><td>Map(version -> 6, timestamp -> null)</td><td>null</td><td>List(1438636061147701)</td><td>0819-110951-buv74slr</td><td>7</td><td>Serializable</td><td>false</td><td>Map(numRestoredFiles -> 1, removedFilesSize -> 0, numRemovedFiles -> 0, restoredFilesSize -> 1295, numOfFilesAfterRestore -> 1, tableSizeAfterRestore -> 1295)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>7</td><td>2026-08-19T20:34:40Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>DELETE</td><td>Map(predicate -> ["true"])</td><td>null</td><td>List(1438636061147701)</td><td>0819-110951-buv74slr</td><td>6</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1295, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 10, numDeletionVectorsUpdated -> 0, numDeletedRows -> 6, scanTimeMs -> 9, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>6</td><td>2026-08-19T20:23:42Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> true)</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>5</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 5, numRemovedBytes -> 5947, p25FileSize -> 1295, numDeletionVectorsRemoved -> 1, minFileSize -> 1295, numAddedFiles -> 1, maxFileSize -> 1295, p75FileSize -> 1295, p50FileSize -> 1295, numAddedBytes -> 1295)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>5</td><td>2026-08-19T20:23:38Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>UPDATE</td><td>Map(predicate -> ["StartsWith(name#1739, A)"])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 1173, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 3678, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1885, numAddedFiles -> 2, numUpdatedRows -> 2, numAddedBytes -> 2382, rewriteTimeMs -> 1765)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>4</td><td>2026-08-19T20:21:31Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1168)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>3</td><td>2026-08-19T20:21:30Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(1438636061147700)</td><td>0819-110951-buv74slr</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1173)</td><td>null</td><td>Databricks-Runtime/14.3.x-photon-scala2.12</td></tr><tr><td>2</td><td>2026-08-19T20:21:26Z</td><td>1264264086812330</td><td>vatsan@worldtabletennis.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partiti ...

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1787170764000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/deletion_vector_ee98ca6a-3134-4c71-9b5a-b0d12c4eda7d.bin</td><td>deletion_vector_ee98ca6a-3134-4c71-9b5a-b0d12c4eda7d.bin</td><td>85</td><td>1787171016000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>1295</td><td>1787171021000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-bd83a397-c6e5-4d0f-a21a-83fd0b640e30.c000.snappy.parquet</td><td>part-00000-bd83a397-c6e5-4d0f-a21a-83fd0b640e30.c000.snappy.parquet</td><td>1191</td><td>1787171016000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d2814aa3-ec00-4a6a-89d0-b32bce2ca4b6.c000.snappy.parquet</td><td>part-00000-d2814aa3-ec00-4a6a-89d0-b32bce2ca4b6.c000.snappy.parquet</td><td>1200</td><td>1787170886000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d2a6c7b7-3838-432b-9610-f7a241c1463b.c000.snappy.parquet</td><td>part-00000-d2a6c7b7-3838-432b-9610-f7a241c1463b.c000.snappy.parquet</td><td>1197</td><td>1787170879000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d6af7353-91a5-4a61-9aa5-26862d97f254.c000.snappy.parquet</td><td>part-00000-d6af7353-91a5-4a61-9aa5-26862d97f254.c000.snappy.parquet</td><td>1168</td><td>1787170891000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-ea7015d9-949b-45cf-9611-de22256e38ed.c000.snappy.parquet</td><td>part-00000-ea7015d9-949b-45cf-9611-de22256e38ed.c000.snappy.parquet</td><td>1173</td><td>1787170889000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00001-603be7f4-e9e4-457d-b9c7-d86a8a88287c.c000.snappy.parquet</td><td>part-00001-603be7f4-e9e4-457d-b9c7-d86a8a88287c.c000.snappy.parquet</td><td>1191</td><td>1787171016000</td></tr></tbody></table></div>

-- %% [markdown]
-- ## VACUUM Command

-- %%
VACUUM employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees</td></tr></tbody></table></div>

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1787170764000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/deletion_vector_ee98ca6a-3134-4c71-9b5a-b0d12c4eda7d.bin</td><td>deletion_vector_ee98ca6a-3134-4c71-9b5a-b0d12c4eda7d.bin</td><td>85</td><td>1787171016000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>1295</td><td>1787171021000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-bd83a397-c6e5-4d0f-a21a-83fd0b640e30.c000.snappy.parquet</td><td>part-00000-bd83a397-c6e5-4d0f-a21a-83fd0b640e30.c000.snappy.parquet</td><td>1191</td><td>1787171016000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d2814aa3-ec00-4a6a-89d0-b32bce2ca4b6.c000.snappy.parquet</td><td>part-00000-d2814aa3-ec00-4a6a-89d0-b32bce2ca4b6.c000.snappy.parquet</td><td>1200</td><td>1787170886000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d2a6c7b7-3838-432b-9610-f7a241c1463b.c000.snappy.parquet</td><td>part-00000-d2a6c7b7-3838-432b-9610-f7a241c1463b.c000.snappy.parquet</td><td>1197</td><td>1787170879000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-d6af7353-91a5-4a61-9aa5-26862d97f254.c000.snappy.parquet</td><td>part-00000-d6af7353-91a5-4a61-9aa5-26862d97f254.c000.snappy.parquet</td><td>1168</td><td>1787170891000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-ea7015d9-949b-45cf-9611-de22256e38ed.c000.snappy.parquet</td><td>part-00000-ea7015d9-949b-45cf-9611-de22256e38ed.c000.snappy.parquet</td><td>1173</td><td>1787170889000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00001-603be7f4-e9e4-457d-b9c7-d86a8a88287c.c000.snappy.parquet</td><td>part-00001-603be7f4-e9e4-457d-b9c7-d86a8a88287c.c000.snappy.parquet</td><td>1191</td><td>1787171016000</td></tr></tbody></table></div>

-- %%
VACUUM employees RETAIN 0 HOURS
-- Out:
-- com.databricks.backend.common.rpc.SparkDriverExceptions$SQLExecutionException: java.lang.IllegalArgumentException: requirement failed: Are you sure you would like to vacuum files with such a low retention period? If you have
-- writers that are currently writing to this table, there is a risk that you may corrupt the
-- state of your Delta table.
-- If you are certain that there are no operations being performed on this table, such as
-- insert/upsert/delete/optimize, then you may turn off this check by setting:
-- spark.databricks.delta.retentionDurationCheck.enabled = false
-- If you are not sure, please use a value not less than "168 hours".
--
-- 	at scala.Predef$.require(Predef.scala:281)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.checkRetentionPeriodSafety(VacuumCommand.scala:94)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.getValidFilesFromSnapshot(VacuumCommand.scala:114)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.$anonfun$gc$2(VacuumCommand.scala:371)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.withOperationTypeTag(DeltaLogging.scala:268)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.withOperationTypeTag$(DeltaLogging.scala:255)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.withOperationTypeTag(VacuumCommand.scala:66)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.$anonfun$recordDeltaOperationInternal$2(DeltaLogging.scala:173)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordFrameProfile(DeltaLogging.scala:337)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordFrameProfile$(DeltaLogging.scala:335)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.recordFrameProfile(VacuumCommand.scala:66)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.$anonfun$recordDeltaOperationInternal$1(DeltaLogging.scala:172)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:512)
-- 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:621)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:646)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.spark.util.PublicDBLogging.withAttributionContext(DatabricksSparkUsageLogger.scala:28)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.spark.util.PublicDBLogging.withAttributionTags(DatabricksSparkUsageLogger.scala:28)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:616)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:521)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperationWithResultTags(DatabricksSparkUsageLogger.scala:28)
-- 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:513)
-- 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:477)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperation(DatabricksSparkUsageLogger.scala:28)
-- 	at com.databricks.spark.util.PublicDBLogging.recordOperation0(DatabricksSparkUsageLogger.scala:107)
-- 	at com.databricks.spark.util.DatabricksSparkUsageLogger.recordOperation(DatabricksSparkUsageLogger.scala:196)
-- 	at com.databricks.spark.util.UsageLogger.recordOperation(UsageLogger.scala:68)
-- 	at com.databricks.spark.util.UsageLogger.recordOperation$(UsageLogger.scala:55)
-- 	at com.databricks.spark.util.DatabricksSparkUsageLogger.recordOperation(DatabricksSparkUsageLogger.scala:155)
-- 	at com.databricks.spark.util.UsageLogging.recordOperation(UsageLogger.scala:429)
-- 	at com.databricks.spark.util.UsageLogging.recordOperation$(UsageLogger.scala:408)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.recordOperation(VacuumCommand.scala:66)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperationInternal(DeltaLogging.scala:171)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperation(DeltaLogging.scala:161)
-- 	at com.databricks.sql.transaction.tahoe.metering.DeltaLogging.recordDeltaOperation$(DeltaLogging.scala:150)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.recordDeltaOperation(VacuumCommand.scala:66)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.$anonfun$gc$1(VacuumCommand.scala:284)
-- 	at com.databricks.sql.acl.CheckPermissions$.$anonfun$trusted$1(CheckPermissions.scala:2237)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag(QueryTagger.scala:62)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag$(QueryTagger.scala:59)
-- 	at com.databricks.sql.util.QueryTagger$.withTag(QueryTagger.scala:152)
-- 	at com.databricks.sql.acl.CheckPermissions$.trusted(CheckPermissions.scala:2237)
-- 	at com.databricks.sql.transaction.tahoe.commands.VacuumCommand$.gc(VacuumCommand.scala:284)
-- 	at com.databricks.sql.transaction.directory.VacuumTableCommand.$anonfun$run$1(VacuumTableCommand.scala:257)
-- 	at com.databricks.sql.acl.CheckPermissions$.$anonfun$trusted$2(CheckPermissions.scala:2257)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag(QueryTagger.scala:62)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag$(QueryTagger.scala:59)
-- 	at com.databricks.sql.util.QueryTagger$.withTag(QueryTagger.scala:152)
-- 	at com.databricks.sql.acl.CheckPermissions$.trusted(CheckPermissions.scala:2257)
-- 	at com.databricks.sql.transaction.directory.VacuumTableCommand.run(VacuumTableCommand.scala:123)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.$anonfun$sideEffectResult$2(commands.scala:84)
-- 	at org.apache.spark.sql.execution.SparkPlan.runCommandWithAetherOff(SparkPlan.scala:178)
-- 	at org.apache.spark.sql.execution.SparkPlan.runCommandInAetherOrSpark(SparkPlan.scala:189)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.$anonfun$sideEffectResult$1(commands.scala:84)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:81)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:80)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:94)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.$anonfun$applyOrElse$4(QueryExecution.scala:379)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:168)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.$anonfun$applyOrElse$3(QueryExecution.scala:379)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$9(SQLExecution.scala:423)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:786)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$1(SQLExecution.scala:293)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId0(SQLExecution.scala:172)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:723)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.$anonfun$applyOrElse$2(QueryExecution.scala:378)
-- 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1192)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.$anonfun$applyOrElse$1(QueryExecution.scala:374)
-- 	at org.apache.spark.sql.execution.QueryExecution.org$apache$spark$sql$execution$QueryExecution$$withMVTagsIfNecessary(QueryExecution.scala:332)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.applyOrElse(QueryExecution.scala:371)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$1$1.applyOrElse(QueryExecution.scala:355)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:505)
-- 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:83)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:505)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:39)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:343)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:339)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:39)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:39)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:481)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$1(QueryExecution.scala:355)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:400)
-- 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:355)
-- 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted$lzycompute(QueryExecution.scala:291)
-- 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:288)
-- 	at org.apache.spark.sql.Dataset.<init>(Dataset.scala:289)
-- 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:127)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1182)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1182)
-- 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:116)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$sql$4(SparkSession.scala:954)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:942)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:977)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:1010)
-- 	at org.apache.spark.sql.SQLContext.sql(SQLContext.scala:696)
-- 	at com.databricks.backend.daemon.driver.DriverLocal$DbClassicStrategy.executeSQLQuery(DriverLocal.scala:312)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.executeSQLSubCommand(DriverLocal.scala:402)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$executeSql$1(DriverLocal.scala:423)
-- 	at scala.collection.immutable.List.map(List.scala:293)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.executeSql(DriverLocal.scala:418)
-- 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:40)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$33(DriverLocal.scala:1169)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:45)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$28(DriverLocal.scala:1160)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:100)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:100)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$1(DriverLocal.scala:1096)
-- 	at com.databricks.backend.daemon.driver.DriverLocal$.$anonfun$maybeSynchronizeExecution$4(DriverLocal.scala:1557)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:773)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$2(DriverWrapper.scala:799)
-- 	at scala.util.Try$.apply(Try.scala:213)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:791)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$3(DriverWrapper.scala:831)
-- 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:621)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:646)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionTags(DriverWrapper.scala:72)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:616)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:521)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.recordOperationWithResultTags(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:831)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommandAndGetError(DriverWrapper.scala:698)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:743)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$runInnerLoop$1(DriverWrapper.scala:573)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:573)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:495)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:292)
-- 	at java.lang.Thread.run(Thread.java:750)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.executeSql(DriverLocal.scala:475)
-- 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:40)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$33(DriverLocal.scala:1169)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:45)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$28(DriverLocal.scala:1160)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:100)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:100)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$1(DriverLocal.scala:1096)
-- 	at com.databricks.backend.daemon.driver.DriverLocal$.$anonfun$maybeSynchronizeExecution$4(DriverLocal.scala:1557)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:773)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$2(DriverWrapper.scala:799)
-- 	at scala.util.Try$.apply(Try.scala:213)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:791)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$3(DriverWrapper.scala:831)
-- 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:621)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:646)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionTags(DriverWrapper.scala:72)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:616)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:521)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.recordOperationWithResultTags(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:831)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommandAndGetError(DriverWrapper.scala:698)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:743)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$runInnerLoop$1(DriverWrapper.scala:573)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:573)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:495)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:292)
-- 	at java.lang.Thread.run(Thread.java:750)

-- %%
SET spark.databricks.delta.retentionDurationCheck.enabled = false;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>spark.databricks.delta.retentionDurationCheck.enabled</td><td>false</td></tr></tbody></table></div>

-- %%
VACUUM employees RETAIN 0 HOURS
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees</td></tr></tbody></table></div>

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/employees/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1787170764000</td></tr><tr><td>dbfs:/user/hive/warehouse/employees/part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>part-00000-1617fcaf-9743-4205-a404-b9fa00725454.c000.snappy.parquet</td><td>1295</td><td>1787171021000</td></tr></tbody></table></div>

-- %%
SELECT * FROM employees@v1
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Adam</td><td>3500.0</td></tr><tr><td>2</td><td>Sarah</td><td>4020.5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Dropping Tables

-- %%
DROP TABLE employees
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM employees
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `employees` cannot be found. Verify the spelling and correctness of the schema and catalog.
-- If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
-- To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01; line 1 pos 14;
-- 'Project [*]
-- +- 'UnresolvedRelation [employees], [], false
--
-- 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.tableNotFound(package.scala:90)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:282)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:255)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:287)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1(TreeNode.scala:286)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$foreachUp$1$adapted(TreeNode.scala:286)
-- 	at scala.collection.Iterator.foreach(Iterator.scala:943)
-- 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
-- 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
-- 	at scala.collection.IterableLike.foreach(IterableLike.scala:74)
-- 	at scala.collection.IterableLike.foreach$(IterableLike.scala:73)
-- 	at scala.collection.AbstractIterable.foreach(Iterable.scala:56)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:286)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:255)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:237)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:392)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:225)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:171)
-- 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:171)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:392)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:447)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:168)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:447)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:407)
-- 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:444)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$analyzed$1(QueryExecution.scala:267)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:396)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:609)
-- 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1192)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:603)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:600)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:600)
-- 	at org.apache.spark.sql.execution.QueryExecution.analyzed$lzycompute(QueryExecution.scala:261)
-- 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:260)
-- 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:236)
-- 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:126)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1182)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1182)
-- 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:116)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$sql$4(SparkSession.scala:954)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1175)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:942)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:977)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:1010)
-- 	at org.apache.spark.sql.SQLContext.sql(SQLContext.scala:696)
-- 	at com.databricks.backend.daemon.driver.DriverLocal$DbClassicStrategy.executeSQLQuery(DriverLocal.scala:312)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.executeSQLSubCommand(DriverLocal.scala:402)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$executeSql$1(DriverLocal.scala:423)
-- 	at scala.collection.immutable.List.map(List.scala:293)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.executeSql(DriverLocal.scala:418)
-- 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:40)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$33(DriverLocal.scala:1169)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:45)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$28(DriverLocal.scala:1160)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:100)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:100)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$1(DriverLocal.scala:1096)
-- 	at com.databricks.backend.daemon.driver.DriverLocal$.$anonfun$maybeSynchronizeExecution$4(DriverLocal.scala:1557)
-- 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:773)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$2(DriverWrapper.scala:799)
-- 	at scala.util.Try$.apply(Try.scala:213)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:791)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$3(DriverWrapper.scala:831)
-- 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:621)
-- 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:646)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:204)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:186)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionTags(DriverWrapper.scala:72)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:616)
-- 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:521)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.recordOperationWithResultTags(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:831)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommandAndGetError(DriverWrapper.scala:698)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:743)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$runInnerLoop$1(DriverWrapper.scala:573)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:150)
-- 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
-- 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:216)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:148)
-- 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:145)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.withAttributionContext(DriverWrapper.scala:72)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:573)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:495)
-- 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:292)
-- 	at java.lang.Thread.run(Thread.java:750)

-- %%
%fs ls 'dbfs:/user/hive/warehouse/employees'
