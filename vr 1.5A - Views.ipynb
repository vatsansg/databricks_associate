-- %% [markdown]
-- ## Preparing Sample Data

-- %%
USE CATALOG hive_metastore;

CREATE TABLE IF NOT EXISTS smartphones
(id INT, name STRING, brand STRING, year INT);

INSERT INTO smartphones
VALUES (1, 'iPhone 14', 'Apple', 2022),
      (2, 'iPhone 13', 'Apple', 2021),
      (3, 'iPhone 6', 'Apple', 2014),
      (4, 'iPad Air', 'Apple', 2013),
      (5, 'Galaxy S22', 'Samsung', 2022),
      (6, 'Galaxy Z Fold', 'Samsung', 2022),
      (7, 'Galaxy S9', 'Samsung', 2016),
      (8, '12 Pro', 'Xiaomi', 2022),
      (9, 'Redmi 11T Pro', 'Xiaomi', 2022),
      (10, 'Redmi Note 11', 'Xiaomi', 2021)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

-- %%
SHOW TABLES
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>ai_query_inference</td><td>false</td></tr><tr><td>default</td><td>auto_mpg_data</td><td>false</td></tr><tr><td>default</td><td>automobile_data</td><td>false</td></tr><tr><td>default</td><td>customer_features</td><td>false</td></tr><tr><td>default</td><td>forecast_prediction_8629057e</td><td>false</td></tr><tr><td>default</td><td>hr_analytics_data</td><td>false</td></tr><tr><td>default</td><td>insurance_data</td><td>false</td></tr><tr><td>default</td><td>player_stats</td><td>false</td></tr><tr><td>default</td><td>smartphones</td><td>false</td></tr><tr><td>default</td><td>weekly_sales_data</td><td>false</td></tr><tr><td>default</td><td>x_test_data</td><td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Creating Stored Views

-- %%
CREATE VIEW view_apple_phones
AS  SELECT * 
    FROM smartphones 
    WHERE brand = 'Apple';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM view_apple_phones;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>brand</th><th>year</th></tr></thead><tbody><tr><td>1</td><td>iPhone 14</td><td>Apple</td><td>2022</td></tr><tr><td>2</td><td>iPhone 13</td><td>Apple</td><td>2021</td></tr><tr><td>3</td><td>iPhone 6</td><td>Apple</td><td>2014</td></tr><tr><td>4</td><td>iPad Air</td><td>Apple</td><td>2013</td></tr></tbody></table></div>

-- %%
SHOW TABLES;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>ai_query_inference</td><td>false</td></tr><tr><td>default</td><td>auto_mpg_data</td><td>false</td></tr><tr><td>default</td><td>automobile_data</td><td>false</td></tr><tr><td>default</td><td>customer_features</td><td>false</td></tr><tr><td>default</td><td>forecast_prediction_8629057e</td><td>false</td></tr><tr><td>default</td><td>hr_analytics_data</td><td>false</td></tr><tr><td>default</td><td>insurance_data</td><td>false</td></tr><tr><td>default</td><td>player_stats</td><td>false</td></tr><tr><td>default</td><td>smartphones</td><td>false</td></tr><tr><td>default</td><td>view_apple_phones</td><td>false</td></tr><tr><td>default</td><td>weekly_sales_data</td><td>false</td></tr><tr><td>default</td><td>x_test_data</td><td>false</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Creating Temporary Views

-- %%
CREATE TEMP VIEW temp_view_phones_brands
AS  SELECT DISTINCT brand
    FROM smartphones;

SELECT * FROM temp_view_phones_brands;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>brand</th></tr></thead><tbody><tr><td>Xiaomi</td></tr><tr><td>Samsung</td></tr><tr><td>Apple</td></tr></tbody></table></div>

-- %%
SHOW TABLES;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>ai_query_inference</td><td>false</td></tr><tr><td>default</td><td>auto_mpg_data</td><td>false</td></tr><tr><td>default</td><td>automobile_data</td><td>false</td></tr><tr><td>default</td><td>customer_features</td><td>false</td></tr><tr><td>default</td><td>forecast_prediction_8629057e</td><td>false</td></tr><tr><td>default</td><td>hr_analytics_data</td><td>false</td></tr><tr><td>default</td><td>insurance_data</td><td>false</td></tr><tr><td>default</td><td>player_stats</td><td>false</td></tr><tr><td>default</td><td>smartphones</td><td>false</td></tr><tr><td>default</td><td>view_apple_phones</td><td>false</td></tr><tr><td>default</td><td>weekly_sales_data</td><td>false</td></tr><tr><td>default</td><td>x_test_data</td><td>false</td></tr><tr><td></td><td>temp_view_phones_brands</td><td>true</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Creating Global Temporary Views

-- %%
CREATE GLOBAL TEMP VIEW global_temp_view_latest_phones
AS SELECT * FROM smartphones
    WHERE year > 2020
    ORDER BY year DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM global_temp.global_temp_view_latest_phones;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>brand</th><th>year</th></tr></thead><tbody><tr><td>6</td><td>Galaxy Z Fold</td><td>Samsung</td><td>2022</td></tr><tr><td>5</td><td>Galaxy S22</td><td>Samsung</td><td>2022</td></tr><tr><td>8</td><td>12 Pro</td><td>Xiaomi</td><td>2022</td></tr><tr><td>1</td><td>iPhone 14</td><td>Apple</td><td>2022</td></tr><tr><td>9</td><td>Redmi 11T Pro</td><td>Xiaomi</td><td>2022</td></tr><tr><td>2</td><td>iPhone 13</td><td>Apple</td><td>2021</td></tr><tr><td>10</td><td>Redmi Note 11</td><td>Xiaomi</td><td>2021</td></tr></tbody></table></div>

-- %%
SHOW TABLES;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>ai_query_inference</td><td>false</td></tr><tr><td>default</td><td>auto_mpg_data</td><td>false</td></tr><tr><td>default</td><td>automobile_data</td><td>false</td></tr><tr><td>default</td><td>customer_features</td><td>false</td></tr><tr><td>default</td><td>forecast_prediction_8629057e</td><td>false</td></tr><tr><td>default</td><td>hr_analytics_data</td><td>false</td></tr><tr><td>default</td><td>insurance_data</td><td>false</td></tr><tr><td>default</td><td>player_stats</td><td>false</td></tr><tr><td>default</td><td>smartphones</td><td>false</td></tr><tr><td>default</td><td>view_apple_phones</td><td>false</td></tr><tr><td>default</td><td>weekly_sales_data</td><td>false</td></tr><tr><td>default</td><td>x_test_data</td><td>false</td></tr><tr><td></td><td>temp_view_phones_brands</td><td>true</td></tr></tbody></table></div>

-- %%
SHOW TABLES IN global_temp;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>global_temp</td><td>global_temp_view_latest_phones</td><td>true</td></tr><tr><td></td><td>temp_view_phones_brands</td><td>true</td></tr></tbody></table></div>

-- %%
SHOW TABLES
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>ai_query_inference</td><td>false</td></tr><tr><td>default</td><td>auto_mpg_data</td><td>false</td></tr><tr><td>default</td><td>automobile_data</td><td>false</td></tr><tr><td>default</td><td>customer_features</td><td>false</td></tr><tr><td>default</td><td>forecast_prediction_8629057e</td><td>false</td></tr><tr><td>default</td><td>hr_analytics_data</td><td>false</td></tr><tr><td>default</td><td>insurance_data</td><td>false</td></tr><tr><td>default</td><td>player_stats</td><td>false</td></tr><tr><td>default</td><td>smartphones</td><td>false</td></tr><tr><td>default</td><td>view_apple_phones</td><td>false</td></tr><tr><td>default</td><td>weekly_sales_data</td><td>false</td></tr><tr><td>default</td><td>x_test_data</td><td>false</td></tr><tr><td></td><td>temp_view_phones_brands</td><td>true</td></tr></tbody></table></div>
